# %% [markdown]
# # Exercícios

# %% [markdown]
# ## Desafio: idiomas do projeto

# %%
import pytesseract
import numpy as np
import cv2 
#from google.colab.patches import cv2_imshow
from matplotlib import pyplot as plt

# %% [raw]
# Cria a pasta 'tessdata'

# %%
# !mkdir tessdata

# %% [raw]
# Fazer o download dos arquivos de idiomas

# %%
# !wget -O ./tessdata/por.traineddata https://github.com/tesseract-ocr/tessdata/blob/main/por.traineddata?raw=true
# !wget -O ./tessdata/eng.traineddata https://github.com/tesseract-ocr/tessdata/blob/main/eng.traineddata?raw=true
# Out:
# zsh:1: no matches found: https://github.com/tesseract-ocr/tessdata/blob/main/por.traineddata?raw=true
# zsh:1: no matches found: https://github.com/tesseract-ocr/tessdata/blob/main/eng.traineddata?raw=true

# %%
img = cv2.imread("../text-recognize/Imagens/Aula2-undersampling.png")
rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(rgb)

# %% [raw]
# Direciona a configuração do Tesseract para a pasta criada.

# %%
config_tesseract = '--tessdata-dir tessdata'
texto = pytesseract.image_to_string(rgb, lang='por', config=config_tesseract)
print(texto)
# Out:
# Undersampling
#
# É uma técnica que consiste em manter todos os dados da classe com menor frequência e
# diminuir a quantidade dos que estão na classe de maior frequência, fazendo com que as
# observações no conjunto possuam dados com a variável alvo equilibrada.

# %%
# !ls tessdata/
# Out:
# eng.traineddata  por.traineddata
